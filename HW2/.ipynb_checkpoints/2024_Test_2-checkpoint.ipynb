# %% [markdown]
# # Методы машинного обучения – Контрольная работа №2
#
# # Нелинейная регрессия

# %% [markdown]
# Линейной регрессии может быть недостаточно для выявления взаимосвязи между признаками $X_{1},X_{2},...,X_{d}$ и откликом $Y$ в случае, когда эта взаимосвязь является нелинейной, поэтому приходится рассматривать более общий случай, когда
#
# $$Y=f\left(\mathbf{X}\right)+\varepsilon=f\left(X_{1},X_{2},...,X_{d}\right)+\varepsilon,$$
#
# где $\varepsilon$ – случайная ошибка, которая предполагается независимой от многомерной случайной величины $\mathbf{X}=\left(X_{1},X_{2},...,X_{d}\right)^{T}\in\mathbb{R}^{d}$, причем $\mathbb{E}\left[\varepsilon\right]=0$.
#
# Импортируем необходимые библиотеки:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds

# %% [markdown]
# При рассмотрении нелинейной регресии часто применяют градиентные методы.
#
# ### Моделирование градиентного спуска
#
# Градиентный спуск — метод нахождения локального минимума или максимума функции с помощью движения вдоль градиента.
#
# Изобразим график функции $y = (x-2.5)^2-1$:

# %%
plot_x = np.linspace(-1., 6., 141)
plot_y = (plot_x-2.5)**2 - 1.
plt.plot(plot_x, plot_y);

# %% [markdown]
# Минимум этой функции достигается в точке $x=2.5$ и равен $-1$.
#
# Для вычисления значений и производной функции $y = (x-2.5)^2-1$ будем использовать следующие функции:

# %%
def J(x_):
    return (x_-2.5)**2 - 1.

def dJ(x_):
    return 2*(x_-2.5)

# %% [markdown]
# Для моделирования градиентного спуска будем использовать функцию `gradient_descent()`, которая будет запоминать и возвращать историю итераций, для визуализации градиентного спуска будем использовать функцию `plot_history()`:

# %%
def gradient_descent(initial_x, eta, n_iters = 1e4, epsilon=1e-8):
    x_ = initial_x
    x_history = [initial_x]
    i_iter = 0

    while i_iter < n_iters:
        gradient = dJ(x_)
        last_x_ = x_
        x_ -= eta * gradient
        x_history.append(x_)

        if(abs(J(x_) - J(last_x_)) < epsilon):
            break
        i_iter += 1

    return x_history

def plot_history(plot_x, x_history):
    plt.plot(plot_x, J(plot_x))
    plt.plot(np.array(x_history), J(np.array(x_history)), color="r", marker='+')
    plt.text(1., 10., f'Кол-во шагов: {len(x_history)}', fontsize=14, color='r')

# %% [markdown]
# Проведем моделирование градиентного спуска с различной скоростью:

# %%
hist = gradient_descent(0., 0.1) # скорость 0.1
plot_history(plot_x, hist)

# %%
hist = gradient_descent(0., 0.01) # скорость 0.01
plot_history(plot_x, hist)

# %%
hist = gradient_descent(0., 0.001) # скорость 0.001
plot_history(plot_x, hist)

# %%
hist = gradient_descent(0., 0.8) # скорость 0.8
plot_history(plot_x, hist)

# %% [markdown]
# При дальнейшем увеличении скорости возникает ошибка, которую нужно обработать:

# %%
try:
    hist = gradient_descent(0., 1.1) # скорость 1.1
    plot_history(plot_x, hist)
except Exception as e:
    print(f"{type(e).__name__}: {e}")
# Out:
# OverflowError: (34, 'Result too large')

# %% [markdown]
# Поэтому ограничимся десятью итерациями:

# %%
hist = gradient_descent(0., 1.1, n_iters=10)
plot_history(plot_x, hist)

# %% [markdown]
# Таким образом, при использовании градиентного спуска важную роль играет скорость (размер шага).
#
# ### Стохастический градиентный спуск
#
# Стохастический градиентный спуск (stochastic gradient descent, SGD) − оптимизационный алгоритм, отличающийся от обычного градиентного спуска тем, что градиент оптимизируемой функции считается на каждом шаге не как сумма градиентов от каждого элемента выборки, а как градиент от одного, случайно выбранного элемента или некоторой подвыборки.
#
# Рассмотрим следующий синтетический набор данных:

# %%
m = 100000 # количество точек в наборе

x = np.random.normal(size=m)
X = x.reshape(-1,1)           # преобразуем вектор в матрицу с одним столбцом
y = 4.*x + 3. + np.random.normal(0, 3, size=m)

plt.scatter(x, y);

# %% [markdown]
# Определим класс `RegressionSGD`, использующий стохастический градиентный спуск (с переменным шагом) при обучении модели:

# %%
class RegressionSGD:

    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
        self._theta = None

    def fit(self, X_train, y_train, n_iters=50, t0=5, t1=50):
        assert X_train.shape[0] == y_train.shape[0], \
            "Размер X_train должен быть равен размеру y_train"
        assert n_iters >= 1

        def dJ_sgd(theta, X_b_i, y_i):
            return X_b_i * (X_b_i.dot(theta) - y_i) * 2.

        def sgd(X_b, y, initial_theta, n_iters=5, t0=5, t1=50):

            def learning_rate(t):
                return t0 / (t + t1)

            theta = initial_theta
            m = len(X_b)
            for i_iter in range(n_iters):
                indexes = np.random.permutation(m)
                X_b_new = X_b[indexes,:]
                y_new = y[indexes]
                for i in range(m):
                    gradient = dJ_sgd(theta, X_b_new[i], y_new[i])
                    theta = theta - learning_rate(i_iter * m + i) * gradient

            return theta

        X_b = np.hstack([np.ones((len(X_train), 1)), X_train])
        initial_theta = np.random.randn(X_b.shape[1])
        self._theta = sgd(X_b, y_train, initial_theta, n_iters, t0, t1)

        self.intercept_ = self._theta[0]
        self.coef_ = self._theta[1:]

        return self

    def predict(self, X_predict):
        assert self.intercept_ is not None and self.coef_ is not None, \
            "Нужно обучить модель перед использованием!"
        assert X_predict.shape[1] == len(self.coef_), \
            "Кол-во признаков в X_predict должно быть равно кол-ву признаков в X_train"

        X_b = np.hstack([np.ones((len(X_predict), 1)), X_predict])
        return X_b.dot(self._theta)

    def score(self, X_test, y_test):
        y_predict = self.predict(X_test)
        return r2_score(y_test, y_predict)

    def __repr__(self):
        return "RegressionSGD()"

# %% [markdown]
# Используем созданный класс для обучения модели линейной регрессии на сгенерированных ранее данных:

# %%
reg = RegressionSGD()
reg.fit(X, y, n_iters=2)
reg.coef_, reg.intercept_
# Out:
# (array([3.97361364]), 3.0155634464912633)

# %%
plt.scatter(x, y)
plot_x = np.linspace(-4, 4, 101)
plt.plot(plot_x, reg.predict(plot_x.reshape(-1,1)), c='r', lw=10);

# %% [markdown]
# ### Полиномиальная регрессия
#
# Полиномиальная регрессия – это форма регрессионного анализа, в которой взаимосвязь между независимой переменной $X$ и зависимой переменной $Y$ моделируется как полином $m$-й степени от $X$
#
# $$Y=f\left(X,\mathbf{w}\right)=w_{0}+w_{1}X+w_{2}X^{2}+...+w_{m}X^{m}+\varepsilon$$
#
# Полиномиальная регрессия может использоваться для решения задачи регрессии для нелинейных данных. В полиномиальной регрессии используется кривая линия, соответствующая полиному степени больше, чем 1. Например, пусть входные данные соответствуют зависимости $y=0.5 x^2+x+2$ (с нормальным шумом):

# %%
x = np.random.uniform(-3, 3, size=100) # вектор
X = x.reshape(-1, 1)                   # матрица с одним стобцом
y = 0.5 * x**2 + x + 2 + np.random.normal(0, 1, size=100)

plt.scatter(x, y);

# %%
reg = RegressionSGD()
reg.fit(X, y, n_iters=2)
y_predict = reg.predict(X)

plt.scatter(x, y)
plt.plot(x, y_predict, color='r');

# %% [markdown]
# Подготовим для модели регрессии входные данные с двумя признаками – линейной и квадратичной зависимостью от независимой переменной:

# %%
X2 = np.hstack([X, X**2]) # соединение массивов по горизонтали
print(X[:5])
print(X2.shape)
print(X2[:5])
# Out:
# [[-1.32249409]
#  [-0.88293408]
#  [-2.83268607]
#  [-0.45594672]
#  [-0.86027721]]
# (100, 2)
# [[-1.32249409  1.74899062]
#  [-0.88293408  0.77957259]
#  [-2.83268607  8.02411035]
#  [-0.45594672  0.20788741]
#  [-0.86027721  0.74007688]]

# %% [markdown]
# Применим к построенным данным модель регрессии на основе SGD и нарисуем набор данных и линию регрессии (функция `np.argsort` возвращает индексы элементов в отсортированном массиве):

# %%
reg2 = RegressionSGD()
reg2.fit(X2, y, n_iters=2000)
y_predict2 = reg2.predict(X2)

plt.scatter(x, y)
plt.plot(np.sort(x), y_predict2[np.argsort(x)], c='r', lw=3);

# %% [markdown]
# Если не использовать функции `sort()` и `argsort()`, то график выглядит так:

# %%
plt.plot(x, y_predict2, c='r');

# %% [markdown]
# Определенные при помощи стохастического градиентного спуска коэффициенты регрессии и смещение близки к значениям, использованным при генерации данных:

# %%
reg2.coef_, reg2.intercept_
# Out:
# (array([1.03851587, 0.56951957]), 1.6188888685555587)

# %% [markdown]
# Альтернативный способ построения наборов данных, содержащих полиномиальные зависимости от исходных данных, состоит в применении класса `PolynomialFeatures` из библиотеки `scikit-learn`:

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=4)
poly.fit(X)
X2s = poly.transform(X)
X2s
# Out:
# array([[ 1.00000000e+00, -1.32249409e+00,  1.74899062e+00,
#         -2.31302977e+00,  3.05896820e+00],
#        [ 1.00000000e+00, -8.82934079e-01,  7.79572587e-01,
#         -6.88311204e-01,  6.07733419e-01],
#        [ 1.00000000e+00, -2.83268607e+00,  8.02411035e+00,
#         -2.27297856e+01,  6.43863469e+01],
#        [ 1.00000000e+00, -4.55946724e-01,  2.07887415e-01,
#         -9.47855857e-02,  4.32171772e-02],
#        [ 1.00000000e+00, -8.60277213e-01,  7.40076884e-01,
#         -6.36671279e-01,  5.47713794e-01],
#        [ 1.00000000e+00,  1.73999908e+00,  3.02759679e+00,
#          5.26801562e+00,  9.16634232e+00],
#        [ 1.00000000e+00, -1.60596736e+00,  2.57913116e+00,
#         -4.14200045e+00,  6.65191753e+00],
#        [ 1.00000000e+00, -1.55401946e+00,  2.41497648e+00,
#         -3.75292044e+00,  5.83211139e+00],
#        [ 1.00000000e+00,  2.85786867e+00,  8.16741336e+00,
#          2.33413948e+01,  6.67066410e+01],
#        [ 1.00000000e+00, -2.06280897e+00,  4.25518086e+00,
#         -8.77762525e+00,  1.81065641e+01],
#        [ 1.00000000e+00, -1.69459929e+00,  2.87166675e+00,
#         -4.86632444e+00,  8.24646994e+00],
#        [ 1.00000000e+00,  2.13454148e+00,  4.55626733e+00,
#          9.72554160e+00,  2.07595720e+01],
#        [ 1.00000000e+00, -7.90245820e-01,  6.24488457e-01,
#         -4.93499393e-01,  3.89985832e-01],
#        [ 1.00000000e+00, -2.60442286e+00,  6.78301842e+00,
#         -1.76658482e+01,  4.60093388e+01],
#        [ 1.00000000e+00, -4.30755625e-01,  1.85550409e-01,
#         -7.99268824e-02,  3.44289542e-02],
#        [ 1.00000000e+00,  1.90712988e+00,  3.63714439e+00,
#          6.93650676e+00,  1.32288193e+01],
#        [ 1.00000000e+00,  7.84323250e-01,  6.15162961e-01,
#          4.82486613e-01,  3.78425468e-01],
#        [ 1.00000000e+00, -2.82842181e+00,  7.99996991e+00,
#         -2.26272893e+01,  6.39995185e+01],
#        [ 1.00000000e+00, -2.05900920e+00,  4.23951890e+00,
#         -8.72920845e+00,  1.79735205e+01],
#        [ 1.00000000e+00, -1.19712143e-01,  1.43309971e-02,
#         -1.71559438e-03,  2.05377479e-04],
#        [ 1.00000000e+00,  1.23694003e+00,  1.53002063e+00,
#          1.89254375e+00,  2.34096311e+00],
#        [ 1.00000000e+00, -4.21332382e-02,  1.77520976e-03,
#         -7.47953359e-05,  3.15136971e-06],
#        [ 1.00000000e+00, -7.30881041e-01,  5.34187097e-01,
#         -3.90427222e-01,  2.85355854e-01],
#        [ 1.00000000e+00, -5.15838045e-01,  2.66088889e-01,
#         -1.37258772e-01,  7.08032968e-02],
#        [ 1.00000000e+00, -7.65811392e-01,  5.86467088e-01,
#         -4.49123177e-01,  3.43943646e-01],
#        [ 1.00000000e+00,  2.78899458e+00,  7.77849074e+00,
#          2.16941685e+01,  6.05049182e+01],
#        [ 1.00000000e+00, -2.41478590e+00,  5.83119092e+00,
#         -1.40810776e+01,  3.40027876e+01],
#        [ 1.00000000e+00, -2.91037164e+00,  8.47026311e+00,
#         -2.46516136e+01,  7.17453572e+01],
#        [ 1.00000000e+00,  2.47746083e+00,  6.13781217e+00,
#          1.52061892e+01,  3.76727382e+01],
#        [ 1.00000000e+00,  2.09953041e-01,  4.40802794e-02,
#          9.25478871e-03,  1.94307103e-03],
#        [ 1.00000000e+00, -1.09677214e-02,  1.20290912e-04,
#         -1.31931721e-06,  1.44699035e-08],
#        [ 1.00000000e+00,  5.29891556e-01,  2.80785062e-01,
#          1.48785633e-01,  7.88402508e-02],
#        [ 1.00000000e+00,  1.01826535e+00,  1.03686433e+00,
#          1.05580302e+00,  1.07508764e+00],
#        [ 1.00000000e+00, -1.17549372e+00,  1.38178548e+00,
#         -1.62428015e+00,  1.90933111e+00],
#        [ 1.00000000e+00,  1.55909152e+00,  2.43076638e+00,
#          3.78978726e+00,  5.90862519e+00],
#        [ 1.00000000e+00,  2.50461004e+00,  6.27307147e+00,
#          1.57115978e+01,  3.93514256e+01],
#        [ 1.00000000e+00,  2.85389740e+00,  8.14473036e+00,
#          2.32442248e+01,  6.63366327e+01],
#        [ 1.00000000e+00, -2.55455926e+00,  6.52577302e+00,
#         -1.66704739e+01,  4.25857136e+01],
#        [ 1.00000000e+00,  1.35779644e+00,  1.84361116e+00,
#          2.50324867e+00,  3.39890213e+00],
#        [ 1.00000000e+00,  1.61645416e+00,  2.61292404e+00,
#          4.22367192e+00,  6.82737203e+00],
#        [ 1.00000000e+00, -1.74495393e+00,  3.04486422e+00,
#         -5.31314779e+00,  9.27119811e+00],
#        [ 1.00000000e+00, -7.15780479e-01,  5.12341695e-01,
#         -3.66724184e-01,  2.62494012e-01],
#        [ 1.00000000e+00,  1.62464609e-01,  2.63947490e-02,
#          4.28821257e-03,  6.96682777e-04],
#        [ 1.00000000e+00,  1.23806982e-01,  1.53281687e-02,
#          1.89773430e-03,  2.34952756e-04],
#        [ 1.00000000e+00, -1.31675603e+00,  1.73384645e+00,
#         -2.28305278e+00,  3.00622352e+00],
#        [ 1.00000000e+00,  1.88239003e+00,  3.54339223e+00,
#          6.67004622e+00,  1.25556285e+01],
#        [ 1.00000000e+00,  1.60749445e+00,  2.58403841e+00,
#          4.15382740e+00,  6.67725449e+00],
#        [ 1.00000000e+00, -7.15817108e-02,  5.12394132e-03,
#         -3.66780486e-04,  2.62547747e-05],
#        [ 1.00000000e+00,  1.51018078e+00,  2.28064598e+00,
#          3.44418772e+00,  5.20134610e+00],
#        [ 1.00000000e+00, -1.17500578e+00,  1.38063857e+00,
#         -1.62225829e+00,  1.90616287e+00],
#        [ 1.00000000e+00, -1.43495069e+00,  2.05908348e+00,
#         -2.95468327e+00,  4.23982479e+00],
#        [ 1.00000000e+00,  9.82629269e-01,  9.65560281e-01,
#          9.48787794e-01,  9.32306657e-01],
#        [ 1.00000000e+00, -2.65713719e+00,  7.06037806e+00,
#         -1.87603931e+01,  4.98489383e+01],
#        [ 1.00000000e+00,  1.92454013e+00,  3.70385473e+00,
#          7.12821707e+00,  1.37185398e+01],
#        [ 1.00000000e+00, -2.68789074e+00,  7.22475663e+00,
#         -1.94193564e+01,  5.21971084e+01],
#        [ 1.00000000e+00,  1.01342877e+00,  1.02703787e+00,
#          1.04082972e+00,  1.05480678e+00],
#        [ 1.00000000e+00, -1.94271156e+00,  3.77412819e+00,
#         -7.33204246e+00,  1.42440436e+01],
#        [ 1.00000000e+00, -2.82330294e+00,  7.97103946e+00,
#         -2.25046591e+01,  6.35374701e+01],
#        [ 1.00000000e+00,  2.94808606e+00,  8.69121144e+00,
#          2.56224393e+01,  7.55371563e+01],
#        [ 1.00000000e+00, -4.27002926e-01,  1.82331498e-01,
#         -7.78560833e-02,  3.32447753e-02],
#        [ 1.00000000e+00, -7.76864886e-01,  6.03519051e-01,
#         -4.68852759e-01,  3.64235245e-01],
#        [ 1.00000000e+00,  4.18567021e-01,  1.75198351e-01,
#          7.33322518e-02,  3.06944622e-02],
#        [ 1.00000000e+00,  2.60268518e+00,  6.77397012e+00,
#          1.76305116e+01,  4.58866712e+01],
#        [ 1.00000000e+00, -2.04951449e+00,  4.20050965e+00,
#         -8.60900540e+00,  1.76442813e+01],
#        [ 1.00000000e+00,  2.59073650e+00,  6.71191563e+00,
#          1.73888048e+01,  4.50498115e+01],
#        [ 1.00000000e+00, -2.84392185e+00,  8.08789151e+00,
#         -2.30013314e+01,  6.54139891e+01],
#        [ 1.00000000e+00,  1.21966396e+00,  1.48758019e+00,
#          1.81434795e+00,  2.21289481e+00],
#        [ 1.00000000e+00, -1.36784038e-01,  1.87098730e-02,
#         -2.55921197e-03,  3.50059347e-04],
#        [ 1.00000000e+00, -1.08734148e+00,  1.18231149e+00,
#         -1.28557632e+00,  1.39786046e+00],
#        [ 1.00000000e+00, -1.20627390e+00,  1.45509672e+00,
#         -1.75524520e+00,  2.11730647e+00],
#        [ 1.00000000e+00,  2.02300246e+00,  4.09253897e+00,
#          8.27921642e+00,  1.67488752e+01],
#        [ 1.00000000e+00, -1.95807153e+00,  3.83404412e+00,
#         -7.50733264e+00,  1.46998943e+01],
#        [ 1.00000000e+00, -9.23556019e-01,  8.52955719e-01,
#         -7.87752388e-01,  7.27533459e-01],
#        [ 1.00000000e+00, -1.78409490e+00,  3.18299462e+00,
#         -5.67876447e+00,  1.01314547e+01],
#        [ 1.00000000e+00, -1.47258838e+00,  2.16851655e+00,
#         -3.19333228e+00,  4.70246402e+00],
#        [ 1.00000000e+00, -2.75091567e-01,  7.56753704e-02,
#         -2.08176562e-02,  5.72676168e-03],
#        [ 1.00000000e+00,  4.42625696e-01,  1.95917507e-01,
#          8.67181230e-02,  3.83836696e-02],
#        [ 1.00000000e+00,  7.31880296e-01,  5.35648768e-01,
#          3.92030779e-01,  2.86919603e-01],
#        [ 1.00000000e+00,  9.07545047e-01,  8.23638013e-01,
#          7.47488599e-01,  6.78379576e-01],
#        [ 1.00000000e+00,  1.25711257e+00,  1.58033201e+00,
#          1.98665524e+00,  2.49744927e+00],
#        [ 1.00000000e+00, -2.15174699e+00,  4.63001510e+00,
#         -9.96262104e+00,  2.14370398e+01],
#        [ 1.00000000e+00,  1.41975718e+00,  2.01571046e+00,
#          2.86181941e+00,  4.06308867e+00],
#        [ 1.00000000e+00, -1.64733691e-01,  2.71371889e-02,
#         -4.47040928e-03,  7.36427020e-04],
#        [ 1.00000000e+00,  1.15209592e+00,  1.32732501e+00,
#          1.52920573e+00,  1.76179169e+00],
#        [ 1.00000000e+00, -1.17553828e+00,  1.38189024e+00,
#         -1.62446487e+00,  1.90962063e+00],
#        [ 1.00000000e+00, -1.10844643e+00,  1.22865348e+00,
#         -1.36189656e+00,  1.50958937e+00],
#        [ 1.00000000e+00,  1.35240344e+00,  1.82899506e+00,
#          2.47353921e+00,  3.34522293e+00],
#        [ 1.00000000e+00, -8.69159093e-01,  7.55437528e-01,
#         -6.56595397e-01,  5.70685859e-01],
#        [ 1.00000000e+00, -2.91186302e+00,  8.47894623e+00,
#         -2.46895299e+01,  7.18925291e+01],
#        [ 1.00000000e+00, -2.65245807e+00,  7.03553380e+00,
#         -1.86614584e+01,  4.94987358e+01],
#        [ 1.00000000e+00, -1.64180363e+00,  2.69551916e+00,
#         -4.42551315e+00,  7.26582356e+00],
#        [ 1.00000000e+00,  9.07381991e-01,  8.23342077e-01,
#          7.47085773e-01,  6.77892175e-01],
#        [ 1.00000000e+00,  9.13213911e-01,  8.33959647e-01,
#          7.61583551e-01,  6.95488694e-01],
#        [ 1.00000000e+00,  7.34642827e-01,  5.39700083e-01,
#          3.96486795e-01,  2.91276180e-01],
#        [ 1.00000000e+00, -2.63985482e+00,  6.96883345e+00,
#         -1.83967085e+01,  4.85646396e+01],
#        [ 1.00000000e+00,  1.68853047e+00,  2.85113516e+00,
#          4.81422861e+00,  8.12897173e+00],
#        [ 1.00000000e+00,  1.87231898e-01,  3.50557837e-02,
#          6.56356093e-03,  1.22890797e-03],
#        [ 1.00000000e+00, -3.10527612e-02,  9.64273978e-04,
#         -2.99433696e-05,  9.29824305e-07],
#        [ 1.00000000e+00,  1.85041990e-01,  3.42405381e-02,
#          6.33593731e-03,  1.17241445e-03],
#        [ 1.00000000e+00,  2.68065590e+00,  7.18591604e+00,
#          1.92629682e+01,  5.16373894e+01]])

# %% [markdown]
# ### Стандартизация и масштабирование признаков
#
# __Стандартизацией__ случайной величины $X$ называют ее линейное преобразование, приводящее к случайной величине с математическим ожиданием $0$ и стандартным отклонением $1$:
#
# $\tilde{X}=\frac{X-\mathbb{E}\left[X\right]}{\sqrt{\mathbb{V}\left[X\right]}},$
#
# где $\mathbb{E}$ – операция вычисления математического ожидания, $\mathbb{V}$ – операция вычисления дисперсии.
#
# Стандартизация набора данных является существенным условием для применения многих алгоритмов машинного обучения, а именно, алгоритмы дают приемлемый результат, только если отдельные признаки распределены примерно как стандартные нормальные величины (с нулевым матожиданием и единичной дисперсией).
#
# Для стандартизации признаков набора данных может быть использована код:

# %%
plt.scatter(x, y);

# %%
x_s, y_s = (x - np.mean(x))/np.std(x), (y - np.mean(y))/np.std(y)
plt.scatter(x_s, y_s)
np.mean(x_s), np.std(x_s), np.mean(y_s), np.std(y_s)
# Out:
# (-1.7763568394002505e-17, 1.0, 7.105427357601002e-17, 1.0)

# %% [markdown]
# Альтернативным вариантом является масштабирование признака между заданным минимальным и максимальным значениями, скажем, между $[0, 1]$. Этот эффект может быть достигнут при помощи кода:

# %%
x_m = (x - np.min(x))/(np.max(x) - np.min(x))
y_m = (y - np.min(y))/(np.max(y) - np.min(y))
plt.scatter(x_m, y_m)
np.min(x_m), np.max(x_m), np.min(y_m), np.max(y_m)
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# ### Выбросы
#
# Выбросами (outliers) называются записи (строки) с характеристиками, которые существенно отличаются от характеристик остальных записей набора данных.
#
# Чтобы убрать выбросы, можно посчитать стандартизованную оценку (Z-score) для каждого признака и убрать записи, содержащие атрибуты с ненормально высоким или низким Z-score (например, $Z>3$ или $Z<-3$). Для нормального распределения вероятность отклонения случайной величины от своего математического ожидания более чем на три стандартных отклонения практически равна нулю (правило трех сигм).
#
# Следующий код показывает результаты стандартизации стоблцов с данными. Отсутствующие значения (NaN) не затрагиваются процессом стандартизации.

# %%
x_out = np.random.normal(size=2000).reshape(1000,2)
plt.scatter(x_out[:,0], x_out[:,1]);

# %%
z_score = 3.
print('Число точек до удаления выбросов = %d' % (x_out.shape[0]))
x2_out = x_out[((x_out >= -z_score).sum(axis=1)==2) & ((x_out <= z_score).sum(axis=1)==2),:] # NB .loc
print('Число точек после удаления выбросов = %d' % (x2_out.shape[0]))
# Out:
# Число точек до удаления выбросов = 1000
# Число точек после удаления выбросов = 991

# %% [markdown]
# ### Полиномиальная регрессия при помощи TensorFlow
#
# Полиномиальная регрессия также может быть реализована при помощи `TensorFlow` и `keras`.
#
# Математически __искусственная нейронная сеть__ (прямого распространения) представляет собой направленный граф с нейронами в качестве вершин и связями между нейронами в виде ребер, причем вход для каждого нейрона является функцией взвешенной суммы выходов всех нейронов, связанных с ним входящими ребрами. Тогда выход нейронной сети равен
#
# $$\mathbf{f\left(\mathbf{x};\theta\right)=\psi_{d}\left(...\psi_{2}\left(\psi_{1}\left(\mathbf{x}\right)\right)\right),\,\psi_{i}\left(\mathbf{x}\right)=\sigma_{i}\left(\mathbf{w^{\left(i\right)}\,x+b^{\left(i\right)}}\right)}$$
#
# Здесь каждый слой сети представляется __функцией активации__ $\mathbf{\sigma_{i}}$ с аргументом в виде взвешенной суммы входных данных $\mathbf{x}$ с __весами__ $\mathbf{w^{\left(i\right)}}$ и __смещениями__ $\mathbf{b^{\left(i\right)}}$. Число слоев $\mathbf{d}$ называется __глубиной__ нейронной сети и количество нейронов в слое представляет собой __ширину__ этого слоя.
#
# Целью глубокого обучения является определение набора параметров сети $\mathbf{\theta=\left\{ w^{\left(i\right)},b^{\left(i\right)}\right\} _{i=1}^{d}}$, который минимизирует __функцию потерь__ $\mathbf{\mathcal{L}(\theta)}$, определяющую качество модели при заданном наборе параметров $\theta$.

# %% [markdown]
# Создадим простейшую нейронную сеть с одним слоем из одного нейрона и двумя входными нейронами:

# %%
reg2_model = tf.keras.Sequential([
    tf.keras.Input(shape=(2,)),
    tf.keras.layers.Dense(units=1)
])

# %% [markdown]
# В такой нейронной сети будет всего три обучаемых параметра (два веса и смещение):

# %%
reg2_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# При компиляции модели в обязательном порядке указывается функция потерь (`loss`), также может быть выбран оптимизатор с параметрами (`optimizer`), метрики для оценки обучения (`metrics`) и некоторые другие другие параметры. В качестве функции потерь и/или метрики могут быть, в частности,  выбраны среднеквадратичная ошибка (MSE) и средняя абсолютная ошибка (MAE). Коэффициента детерминации $R^2$ среди стандартных функций потерь и метрик нет, но он легко может быть вычислен непосредственно по показателю MSE и общей дисперсии целевой переменной.

# %%
reg2_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
print(X2[0:5])
print(y[0:5])
# Out:
# [[-1.32249409  1.74899062]
#  [-0.88293408  0.77957259]
#  [-2.83268607  8.02411035]
#  [-0.45594672  0.20788741]
#  [-0.86027721  0.74007688]]
# [ 2.54425013 -0.5831825   2.29567509  0.3018236   0.75235631]

# %% [markdown]
# Обучаем нейронную сеть на полиномиальных зависимостях:

# %%
history = reg2_model.fit(
    X2, y,
    epochs=100,
    # уровень выводимой информации
    verbose=1,
    # проверка (валидация) на 30% обучающих данных
    validation_split = 0.3)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.5580 - val_loss: 2.9775
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4921 - val_loss: 2.0524
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5264 - val_loss: 1.2549
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7189 - val_loss: 0.9563
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3872 - val_loss: 0.8269
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1050 - val_loss: 0.8513
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1095 - val_loss: 0.8311
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1672 - val_loss: 0.7547
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0418 - val_loss: 0.6866
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8691 - val_loss: 0.6686
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9082 - val_loss: 0.6585
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9397 - val_loss: 0.6148
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9261 - val_loss: 0.6222
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8541 - val_loss: 0.6708
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9136 - val_loss: 0.7047
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9210 - val_loss: 0.6775
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.8783 - val_loss: 0.6751
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8920 - val_loss: 0.6937
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8737 - val_loss: 0.6737
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8723 - val_loss: 0.6755
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8277 - val_loss: 0.6708
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8739 - val_loss: 0.6608
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8336 - val_loss: 0.6616
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8512 - val_loss: 0.6506
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8666 - val_loss: 0.6686
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8756 - val_loss: 0.6953
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8821 - val_loss: 0.6810
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8829 - val_loss: 0.6509
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8753 - val_loss: 0.6606
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8422 - val_loss: 0.6807
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8874 - val_loss: 0.6861
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8333 - val_loss: 0.6690
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8849 - val_loss: 0.6438
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8594 - val_loss: 0.6318
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8541 - val_loss: 0.6401
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8283 - val_loss: 0.6665
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8645 - val_loss: 0.6969
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9454 - val_loss: 0.7337
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9129 - val_loss: 0.6747
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8469 - val_loss: 0.6664
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8722 - val_loss: 0.6834
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8718 - val_loss: 0.6655
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8710 - val_loss: 0.6700
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8572 - val_loss: 0.6607
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9057 - val_loss: 0.6532
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8934 - val_loss: 0.6357
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8542 - val_loss: 0.6442
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8370 - val_loss: 0.6380
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8391 - val_loss: 0.6561
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8524 - val_loss: 0.6743
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8376 - val_loss: 0.6961
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8523 - val_loss: 0.7144
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8809 - val_loss: 0.6965
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8648 - val_loss: 0.6536
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8582 - val_loss: 0.6317
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9006 - val_loss: 0.6296
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8136 - val_loss: 0.6635
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8628 - val_loss: 0.7228
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8692 - val_loss: 0.6989
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8880 - val_loss: 0.6844
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8764 - val_loss: 0.6482
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8235 - val_loss: 0.6197
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8813 - val_loss: 0.6384
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9495 - val_loss: 0.6222
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8557 - val_loss: 0.6454
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8688 - val_loss: 0.6877
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8813 - val_loss: 0.6920
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8925 - val_loss: 0.6858
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8700 - val_loss: 0.6975
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8409 - val_loss: 0.6648
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8643 - val_loss: 0.6529
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8694 - val_loss: 0.6729
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9237 - val_loss: 0.6767
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8865 - val_loss: 0.7139
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8810 - val_loss: 0.7566
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8627 - val_loss: 0.7256
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8481 - val_loss: 0.6803
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8914 - val_loss: 0.6557
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9012 - val_loss: 0.6908
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9259 - val_loss: 0.6680
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8621 - val_loss: 0.6764
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8619 - val_loss: 0.7027
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8673 - val_loss: 0.7352
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8320 - val_loss: 0.7563
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.9180 - val_loss: 0.7193
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8679 - val_loss: 0.6719
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.8568 - val_loss: 0.6483
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8807 - val_loss: 0.6500
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8145 - val_loss: 0.6623
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8620 - val_loss: 0.6589
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8841 - val_loss: 0.6581
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9078 - val_loss: 0.6749
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8668 - val_loss: 0.7052
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8480 - val_loss: 0.6964
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8446 - val_loss: 0.6612
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8933 - val_loss: 0.6410
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8740 - val_loss: 0.6415
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8706 - val_loss: 0.6437
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8870 - val_loss: 0.6452
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9093 - val_loss: 0.6700

# %% [markdown]
# Метод `fit` возвращает объект `history`, в котором для задачи регрессии обычно есть ключи `'loss'` и `'val_loss'`. Можно визуализировать историю обучения при помощи следующей функции:

# %%
def plot_loss(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylim([0, max(history.history['loss'])*0.5])
  plt.title('Функция потерь при обучении модели')
  plt.xlabel('Эпохи обучения')
  plt.ylabel('Функция потерь')
  plt.legend(['Обучающая выборка', 'Тестовая выборка'], loc='upper right')
  plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# При помощи обученной модели можно выполнить прогноз:

# %%
y_predict_reg2 = reg2_model.predict(X2)

plt.scatter(x, y, label='набор данных')
plt.plot(np.sort(x), y_predict_reg2[np.argsort(x)], color='r', label='прогноз')
plt.legend(loc='upper left')
plt.grid();
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# ### Нелинейная парная регрессия при помощи TensorFlow
#
# Универсальная теорема аппроксимации утверждает, что любую непрерывную функцию можно с любой степенью точности аппроксимировать нейронной сетью с одним скрытым слоем с функцией активации сигмоида $\sigma\left(\mathrm{x}\right)=\frac{1}{1+\exp\left(-\mathrm{x}\right)}$.
#
# Построим и обучим нейронную сеть такого типа для рассматриваемого набора данных:

# %%
uni_model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(units=512, activation='sigmoid'),
    tf.keras.layers.Dense(units=1)
])

# %%
uni_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 512)                 │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,537 (6.00 KB)
#  Trainable params: 1,537 (6.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
uni_model.compile(loss='mse',
                  optimizer=tf.optimizers.Adam(learning_rate=0.1),
                  metrics=['mae'])

# %%
X.shape
print(X[0:5])
print(y[0:5])
# Out:
# [[-1.32249409]
#  [-0.88293408]
#  [-2.83268607]
#  [-0.45594672]
#  [-0.86027721]]
# [ 2.54425013 -0.5831825   2.29567509  0.3018236   0.75235631]

# %%
history = uni_model.fit(
    X, y,
    epochs=100,
    # уровень выводимой информации
    verbose=1,
    # проверка (валидация) на 20% обучающих данных
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 193.1860 - mae: 9.7163 - val_loss: 102.0010 - val_mae: 9.8942
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 176.1952 - mae: 12.6977 - val_loss: 63.6066 - val_mae: 7.8262
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 46.0779 - mae: 6.0249 - val_loss: 100.8661 - val_mae: 9.9293
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 101.4532 - mae: 9.8691 - val_loss: 52.1626 - val_mae: 7.0287
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 33.2749 - mae: 5.1132 - val_loss: 10.5262 - val_mae: 2.7833
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 25.8509 - mae: 4.0284 - val_loss: 32.5991 - val_mae: 5.2443
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.5850 - mae: 4.9312 - val_loss: 2.8404 - val_mae: 1.2685
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1482 - mae: 1.6918 - val_loss: 19.5419 - val_mae: 3.9139
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.6571 - mae: 3.6627 - val_loss: 12.5493 - val_mae: 3.1895
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8766 - mae: 2.5324 - val_loss: 2.1596 - val_mae: 1.1636
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2299 - mae: 1.6057 - val_loss: 5.4330 - val_mae: 1.9463
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3944 - mae: 2.3002 - val_loss: 3.0082 - val_mae: 1.2874
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0646 - mae: 1.7712 - val_loss: 2.7227 - val_mae: 1.4500
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3573 - mae: 1.5005 - val_loss: 5.6907 - val_mae: 2.0553
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0646 - mae: 1.8200 - val_loss: 3.8238 - val_mae: 1.6641
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.7342 - mae: 1.6267 - val_loss: 1.9715 - val_mae: 1.2278
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.9267 - mae: 1.3647 - val_loss: 2.0184 - val_mae: 1.1265
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4790 - mae: 1.4946 - val_loss: 1.9122 - val_mae: 1.1844
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0128 - mae: 1.3933 - val_loss: 2.5174 - val_mae: 1.4067
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7046 - mae: 1.3987 - val_loss: 2.7739 - val_mae: 1.4574
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8029 - mae: 1.4270 - val_loss: 2.3801 - val_mae: 1.3476
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6668 - mae: 1.3872 - val_loss: 2.0483 - val_mae: 1.2036
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5809 - mae: 1.3522 - val_loss: 2.0611 - val_mae: 1.2107
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5136 - mae: 1.3287 - val_loss: 2.2859 - val_mae: 1.3059
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4887 - mae: 1.3309 - val_loss: 2.1809 - val_mae: 1.2727
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5368 - mae: 1.3559 - val_loss: 1.9625 - val_mae: 1.1953
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6825 - mae: 1.4029 - val_loss: 1.8998 - val_mae: 1.1857
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3396 - mae: 1.2747 - val_loss: 1.9994 - val_mae: 1.2302
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2173 - mae: 1.2322 - val_loss: 2.0295 - val_mae: 1.2331
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3018 - mae: 1.2623 - val_loss: 1.7299 - val_mae: 1.1295
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2373 - mae: 1.2255 - val_loss: 1.5613 - val_mae: 1.0526
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0532 - mae: 1.1677 - val_loss: 1.5846 - val_mae: 1.0577
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0294 - mae: 1.1321 - val_loss: 1.6871 - val_mae: 1.0846
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8541 - mae: 1.1064 - val_loss: 1.4590 - val_mae: 0.9906
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7807 - mae: 1.1228 - val_loss: 1.3348 - val_mae: 0.9262
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6177 - mae: 1.0501 - val_loss: 1.2419 - val_mae: 0.8779
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6119 - mae: 1.0304 - val_loss: 1.2332 - val_mae: 0.8656
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5535 - mae: 1.0085 - val_loss: 1.2842 - val_mae: 0.8686
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3446 - mae: 0.9362 - val_loss: 1.2483 - val_mae: 0.8389
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2844 - mae: 0.9069 - val_loss: 1.0891 - val_mae: 0.7634
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3722 - mae: 0.9230 - val_loss: 0.9591 - val_mae: 0.7228
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2664 - mae: 0.8925 - val_loss: 1.0289 - val_mae: 0.7246
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2158 - mae: 0.8828 - val_loss: 1.2424 - val_mae: 0.8109
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3627 - mae: 0.9548 - val_loss: 0.9835 - val_mae: 0.6875
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1768 - mae: 0.8904 - val_loss: 0.8943 - val_mae: 0.6867
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2345 - mae: 0.8905 - val_loss: 0.8799 - val_mae: 0.6885
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0453 - mae: 0.8124 - val_loss: 0.9703 - val_mae: 0.6515
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0315 - mae: 0.8112 - val_loss: 0.9313 - val_mae: 0.6524
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9023 - mae: 0.7587 - val_loss: 0.8902 - val_mae: 0.6747
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1188 - mae: 0.8411 - val_loss: 0.9096 - val_mae: 0.6862
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0044 - mae: 0.8072 - val_loss: 0.9718 - val_mae: 0.7096
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9118 - mae: 0.7662 - val_loss: 0.8907 - val_mae: 0.7001
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9560 - mae: 0.7914 - val_loss: 0.8977 - val_mae: 0.6927
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8619 - mae: 0.7370 - val_loss: 1.0132 - val_mae: 0.6991
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0523 - mae: 0.8199 - val_loss: 0.9379 - val_mae: 0.6905
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8710 - mae: 0.7365 - val_loss: 0.9245 - val_mae: 0.6879
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9448 - mae: 0.7851 - val_loss: 0.9164 - val_mae: 0.6974
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.9181 - mae: 0.7657 - val_loss: 0.9387 - val_mae: 0.6967
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8986 - mae: 0.7590 - val_loss: 0.9472 - val_mae: 0.7014
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8475 - mae: 0.7390 - val_loss: 0.9253 - val_mae: 0.7165
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0168 - mae: 0.8065 - val_loss: 0.9193 - val_mae: 0.7127
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9203 - mae: 0.7716 - val_loss: 0.9851 - val_mae: 0.6977
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8811 - mae: 0.7614 - val_loss: 0.9281 - val_mae: 0.7053
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9499 - mae: 0.7840 - val_loss: 0.9174 - val_mae: 0.7146
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9496 - mae: 0.7876 - val_loss: 0.9187 - val_mae: 0.7156
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8703 - mae: 0.7536 - val_loss: 1.0460 - val_mae: 0.7129
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9095 - mae: 0.7524 - val_loss: 0.9208 - val_mae: 0.7170
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9219 - mae: 0.7630 - val_loss: 0.9473 - val_mae: 0.7465
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0061 - mae: 0.7962 - val_loss: 0.9615 - val_mae: 0.6948
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9519 - mae: 0.7718 - val_loss: 0.9585 - val_mae: 0.7018
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9539 - mae: 0.7791 - val_loss: 0.9214 - val_mae: 0.7337
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8520 - mae: 0.7477 - val_loss: 0.9218 - val_mae: 0.7388
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8820 - mae: 0.7679 - val_loss: 0.9241 - val_mae: 0.7195
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8152 - mae: 0.7359 - val_loss: 0.9572 - val_mae: 0.7201
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8788 - mae: 0.7573 - val_loss: 0.9354 - val_mae: 0.7286
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8292 - mae: 0.7292 - val_loss: 0.9368 - val_mae: 0.7162
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9350 - mae: 0.7737 - val_loss: 0.9247 - val_mae: 0.7129
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9036 - mae: 0.7705 - val_loss: 0.9418 - val_mae: 0.6982
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9172 - mae: 0.7715 - val_loss: 0.9143 - val_mae: 0.7157
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8982 - mae: 0.7517 - val_loss: 0.9123 - val_mae: 0.7135
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9612 - mae: 0.8015 - val_loss: 0.9371 - val_mae: 0.6886
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9452 - mae: 0.7632 - val_loss: 0.9611 - val_mae: 0.6878
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7802 - mae: 0.6782 - val_loss: 0.9214 - val_mae: 0.6843
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8927 - mae: 0.7617 - val_loss: 0.9029 - val_mae: 0.7420
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8657 - mae: 0.7698 - val_loss: 0.8887 - val_mae: 0.7301
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9692 - mae: 0.8022 - val_loss: 0.8969 - val_mae: 0.6844
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8457 - mae: 0.7371 - val_loss: 0.9856 - val_mae: 0.6864
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8853 - mae: 0.7395 - val_loss: 0.9082 - val_mae: 0.6843
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8458 - mae: 0.7336 - val_loss: 0.8941 - val_mae: 0.7517
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9291 - mae: 0.7870 - val_loss: 0.8721 - val_mae: 0.7206
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8918 - mae: 0.7780 - val_loss: 0.9841 - val_mae: 0.6846
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9596 - mae: 0.7740 - val_loss: 0.9135 - val_mae: 0.6799
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8745 - mae: 0.7399 - val_loss: 0.8774 - val_mae: 0.6984
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8720 - mae: 0.7403 - val_loss: 0.8755 - val_mae: 0.7204
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9593 - mae: 0.7983 - val_loss: 0.9024 - val_mae: 0.6959
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8091 - mae: 0.7265 - val_loss: 0.9100 - val_mae: 0.6803
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8839 - mae: 0.7638 - val_loss: 0.8758 - val_mae: 0.7020
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8297 - mae: 0.7347 - val_loss: 0.9230 - val_mae: 0.7006
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9058 - mae: 0.7665 - val_loss: 0.8831 - val_mae: 0.6931
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8154 - mae: 0.7266 - val_loss: 0.8859 - val_mae: 0.6881

# %%
plot_loss(history)

# %%
y_predict_uni = uni_model.predict(X)

plt.scatter(x, y, label='набор данных')
plt.plot(np.sort(x), y_predict_uni[np.argsort(x)], color='r', label='прогноз')
plt.legend(loc='upper left')
plt.grid();
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# ### Нелинейная множественная регрессия при помощи TensorFlow
#
# При помощи нейронных сетей с нелинейными функциями активации нейронов можно успешно решать задачи нелинейной регрессии.
#
# Загрузим из TesorFlow Datasets набор `howell` с демографическими данными жителей Калахари:

# %%
ds = tfds.load("howell", split='train')
df = tfds.as_dataframe(ds)
df
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to ~\tensorflow_datasets\howell\1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 ds = tfds.load("howell", split='train')
#       2 df = tfds.as_dataframe(ds)
#       3 df
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\load.py:327, in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     325 if download:
#     326   download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 327   dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     329 if as_dataset_kwargs is None:
#     330   as_dataset_kwargs = {}
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\dataset_builder.py:481, in DatasetBuilder.download_and_prepare(self, download_dir, download_config, file_format)
#     479   self.info.read_from_directory(self._data_dir)
#     480 else:
# --> 481   self._download_and_prepare(
#     482       dl_manager=dl_manager,
#     483       download_config=download_config,
#     484   )
#     486   # NOTE: If modifying the lines below to put additional information in
#     487   # DatasetInfo, you'll likely also want to update
#     488   # DatasetInfo.read_from_directory to possibly restore these attributes
#     489   # when reading from package data.
#     490   self.info.download_size = dl_manager.downloaded_size
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\dataset_builder.py:1184, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, download_config)
#    1182 else:
#    1183   optional_pipeline_kwargs = {}
# -> 1184 split_generators = self._split_generators(  # pylint: disable=unexpected-keyword-arg
#    1185     dl_manager, **optional_pipeline_kwargs)
#    1186 # TODO(tfds): Could be removed once all datasets are migrated.
#    1187 # https://github.com/tensorflow/datasets/issues/2537
#    1188 # Legacy mode (eventually convert list[SplitGeneratorLegacy] -> dict)
#    1189 split_generators = split_builder.normalize_legacy_split_generators(
#    1190     split_generators=split_generators,
#    1191     generator_fn=self._generate_examples,
#    1192     is_beam=isinstance(self, BeamBasedBuilder),
#    1193 )
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\structured\howell\howell.py:85, in Howell._split_generators(self, dl_manager)
#      83 def _split_generators(self, dl_manager: tfds.download.DownloadManager):
#      84   """Returns SplitGenerators."""
# ---> 85   file_path = dl_manager.download_and_extract(URL)
#      86   return {tfds.Split.TRAIN: self._generate_examples(file_path)}
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:633, in DownloadManager.download_and_extract(self, url_or_urls)
#     631 with self._downloader.tqdm():
#     632   with self._extractor.tqdm():
# --> 633     return _map_promise(self._download_extract, url_or_urls)
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:766, in _map_promise(map_fn, all_inputs)
#     764 """Map the function into each element and resolve the promise."""
#     765 all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 766 res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     767 return res
#
# File C:\Python312\Lib\site-packages\tensorflow\python\util\nest.py:628, in map_structure(func, *structure, **kwargs)
#     542 @tf_export("nest.map_structure")
#     543 def map_structure(func, *structure, **kwargs):
#     544   """Creates a new structure by applying `func` to each atom in `structure`.
#     545
#     546   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     626     ValueError: If wrong keyword arguments are provided.
#     627   """
# --> 628   return nest_util.map_structure(
#     629       nest_util.Modality.CORE, func, *structure, **kwargs
#     630   )
#
# File C:\Python312\Lib\site-packages\tensorflow\python\util\nest_util.py:1065, in map_structure(modality, func, *structure, **kwargs)
#     968 """Creates a new structure by applying `func` to each atom in `structure`.
#     969
#     970 - For Modality.CORE: Refer to
#    (...)
#    1062   ValueError: If wrong keyword arguments are provided.
#    1063 """
#    1064 if modality == Modality.CORE:
# -> 1065   return _tf_core_map_structure(func, *structure, **kwargs)
#    1066 elif modality == Modality.DATA:
#    1067   return _tf_data_map_structure(func, *structure, **kwargs)
#
# File C:\Python312\Lib\site-packages\tensorflow\python\util\nest_util.py:1105, in _tf_core_map_structure(func, *structure, **kwargs)
#    1100 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1101 entries = zip(*flat_structure)
#    1103 return _tf_core_pack_sequence_as(
#    1104     structure[0],
# -> 1105     [func(*x) for x in entries],
#    1106     expand_composites=expand_composites,
#    1107 )
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:766, in _map_promise.<locals>.<lambda>(p)
#     764 """Map the function into each element and resolve the promise."""
#     765 all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 766 res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     767 return res
#
# File C:\Python312\Lib\site-packages\promise\promise.py:512, in Promise.get(self, timeout)
#     510 target = self._target()
#     511 self._wait(timeout or DEFAULT_TIMEOUT)
# --> 512 return self._target_settled_value(_raise=True)
#
# File C:\Python312\Lib\site-packages\promise\promise.py:516, in Promise._target_settled_value(self, _raise)
#     514 def _target_settled_value(self, _raise=False):
#     515     # type: (bool) -> Any
# --> 516     return self._target()._settled_value(_raise)
#
# File C:\Python312\Lib\site-packages\promise\promise.py:226, in Promise._settled_value(self, _raise)
#     224 if _raise:
#     225     raise_val = self._fulfillment_handler0
# --> 226     reraise(type(raise_val), raise_val, self._traceback)
#     227 return self._fulfillment_handler0
#
# File ~\AppData\Roaming\Python\Python312\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File C:\Python312\Lib\site-packages\promise\promise.py:87, in try_catch(handler, *args, **kwargs)
#      84 def try_catch(handler, *args, **kwargs):
#      85     # type: (Callable, Any, Any) -> Union[Tuple[Any, None], Tuple[None, Tuple[Exception, Optional[TracebackType]]]]
#      86     try:
# ---> 87         return (handler(*args, **kwargs), None)
#      88     except Exception as e:
#      89         tb = exc_info()[2]
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:358, in DownloadManager._download.<locals>.<lambda>(dl_result)
#     354   future = self._downloader.download(
#     355       url, download_tmp_dir, verify=self._verify_ssl)
#     357 # Post-process the result
# --> 358 return future.then(lambda dl_result: self._register_or_validate_checksums(  # pylint: disable=g-long-lambda
#     359     url=url,
#     360     path=dl_result.path,
#     361     computed_url_info=dl_result.url_info,
#     362     expected_url_info=expected_url_info,
#     363     checksum_path=checksum_path,
#     364     url_path=url_path,
#     365 ))
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:421, in DownloadManager._register_or_validate_checksums(self, path, url, expected_url_info, computed_url_info, checksum_path, url_path)
#     403 else:
#     404   # Eventually validate checksums
#     405   # Note:
#    (...)
#     411   #   download). This is expected as it might mean the downloaded file
#     412   #   was corrupted. Note: The tmp file isn't deleted to allow inspection.
#     413   _validate_checksums(
#     414       url=url,
#     415       path=path,
#    (...)
#     418       force_checksums_validation=self._force_checksums_validation,
#     419   )
# --> 421 return self._rename_and_get_final_dl_path(
#     422     url=url,
#     423     path=path,
#     424     expected_url_info=expected_url_info,
#     425     computed_url_info=computed_url_info,
#     426     checksum_path=checksum_path,
#     427     url_path=url_path,
#     428 )
#
# File C:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:445, in DownloadManager._rename_and_get_final_dl_path(self, url, path, expected_url_info, computed_url_info, checksum_path, url_path)
#     439 """Eventually rename the downloaded file if checksums were recorded."""
#     440 # `path` can be:
#     441 # * Manually downloaded
#     442 # * (cached) checksum_path
#     443 # * (cached) url_path
#     444 # * `tmp_dir/file` (downloaded path)
# --> 445 if self._manual_dir and path.is_relative_to(self._manual_dir):
#     446   return path  # Manually downloaded data
#     447 elif path == checksum_path:  # Path already at final destination
#
# File C:\Python312\Lib\site-packages\etils\epath\abstract_path.py:78, in Path.is_relative_to(self, *other)
#      76 """Return True if the path is relative to another path or False."""
#      77 try:
# ---> 78   self.relative_to(*other)
#      79   return True
#      80 except ValueError:
#
# File C:\Python312\Lib\pathlib.py:679, in PurePath.relative_to(self, other, walk_up, *_deprecated)
#     677 other = self.with_segments(other, *_deprecated)
#     678 for step, path in enumerate([other] + list(other.parents)):
# --> 679     if self.is_relative_to(path):
#     680         break
#     681     elif not walk_up:
#
# File C:\Python312\Lib\site-packages\etils\epath\abstract_path.py:78, in Path.is_relative_to(self, *other)
#      76 """Return True if the path is relative to another path or False."""
#      77 try:
# ---> 78   self.relative_to(*other)
#      79   return True
#      80 except ValueError:
#
# File C:\Python312\Lib\pathlib.py:679, in PurePath.relative_to(self, other, walk_up, *_deprecated)
#     677 other = self.with_segments(other, *_deprecated)
#     678 for step, path in enumerate([other] + list(other.parents)):
# --> 679     if self.is_relative_to(path):
#     680         break
#     681     elif not walk_up:
#
#     [... skipping similar frames: Path.is_relative_to at line 78 (741 times), PurePath.relative_to at line 679 (740 times)]
#
# File C:\Python312\Lib\pathlib.py:679, in PurePath.relative_to(self, other, walk_up, *_deprecated)
#     677 other = self.with_segments(other, *_deprecated)
#     678 for step, path in enumerate([other] + list(other.parents)):
# --> 679     if self.is_relative_to(path):
#     680         break
#     681     elif not walk_up:
#
# File C:\Python312\Lib\site-packages\etils\epath\abstract_path.py:78, in Path.is_relative_to(self, *other)
#      76 """Return True if the path is relative to another path or False."""
#      77 try:
# ---> 78   self.relative_to(*other)
#      79   return True
#      80 except ValueError:
#
# File C:\Python312\Lib\pathlib.py:677, in PurePath.relative_to(self, other, walk_up, *_deprecated)
#     672     msg = ("support for supplying more than one positional argument "
#     673            "to pathlib.PurePath.relative_to() is deprecated and "
#     674            "scheduled for removal in Python {remove}")
#     675     warnings._deprecated("pathlib.PurePath.relative_to(*args)", msg,
#     676                          remove=(3, 14))
# --> 677 other = self.with_segments(other, *_deprecated)
#     678 for step, path in enumerate([other] + list(other.parents)):
#     679     if self.is_relative_to(path):
#
# File C:\Python312\Lib\pathlib.py:385, in PurePath.with_segments(self, *pathsegments)
#     380 def with_segments(self, *pathsegments):
#     381     """Construct a new path object from any number of path-like objects.
#     382     Subclasses may override this method to customize how new path objects
#     383     are created from methods like `iterdir()`.
#     384     """
# --> 385     return type(self)(*pathsegments)
#
# File C:\Python312\Lib\site-packages\etils\epath\gpath.py:81, in _GPath.__new__(cls, *parts)
#      80 def __new__(cls: Type[_P], *parts: PathLike) -> _P:
# ---> 81   full_path = '/'.join(os.fspath(p) for p in parts)
#      82   if full_path.startswith(_URI_PREFIXES):
#      83     prefix, _ = full_path.split('://', maxsplit=1)
#
# File C:\Python312\Lib\site-packages\etils\epath\gpath.py:81, in <genexpr>(.0)
#      80 def __new__(cls: Type[_P], *parts: PathLike) -> _P:
# ---> 81   full_path = '/'.join(os.fspath(p) for p in parts)
#      82   if full_path.startswith(_URI_PREFIXES):
#      83     prefix, _ = full_path.split('://', maxsplit=1)
#
# File C:\Python312\Lib\site-packages\etils\epath\gpath.py:133, in _GPath.__fspath__(self)
#     132 def __fspath__(self) -> str:
# --> 133   return self._path_str
#
# File C:\Python312\Lib\site-packages\etils\epath\gpath.py:130, in _GPath._path_str(self)
#     128   return self._PATH.join(f'{uri_scheme}://', *self.parts[2:])
#     129 else:
# --> 130   return self._PATH.join(*self.parts) if self.parts else '.'
#
# File <frozen ntpath>:121, in join(path, *paths)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# Изучим зависимость возраста от роста и веса:

# %%
X = np.array(df[['height','weight']])
y = np.array(df[['age']]).reshape(-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 X = np.array(df[['height','weight']])
#       2 y = np.array(df[['age']]).reshape(-1)
#
# NameError: name 'df' is not defined

# %%
X.shape, y.shape

# %% [markdown]
# ### Визуализация трехмерных данных
#
# Для построения 3d графиков необходимо импортировать необходимые модули:

# %%
from mpl_toolkits import mplot3d
# или from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = plt.axes(projection='3d') # или ax = fig.add_subplot(111, projection='3d')

# %% [markdown]
# Для построения точечного графика можно использовать функцию `scatter()`, которой передаются три параметра для координат точек по осям X, Y и Z.

# %%
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')

xs = X[:,0]
ys = X[:,1]
zs = y

ax.scatter( xs, ys, zs, s=100 )
ax.set_xlabel('Рост')
ax.set_ylabel('Вес')
ax.set_zlabel('Возраст')
ax.view_init( azim=-120, elev=25 )

# %% [markdown]
# ### Глубокая нейронная сеть для задачи регрессии
#
# Используем слой нормализации, адаптированный к обоим независимым признакам:

# %%
feature_normalizer = tf.keras.layers.Normalization(axis=None,input_shape=(2,))
feature_normalizer.adapt(X)
print(X[0:5])
# Out:
# [[-1.32249409]
#  [-0.88293408]
#  [-2.83268607]
#  [-0.45594672]
#  [-0.86027721]]
# C:\Python312\Lib\site-packages\keras\src\layers\preprocessing\normalization.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Создадим нейронную сеть со слоем нормализации, четырьмя скрытыми плотными слоями с 64 нейронами и функцией активации ReLu и выходным слоем из одного нейрона:

# %%
large_model = tf.keras.Sequential([
    feature_normalizer,
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

large_model.summary()

# %% [markdown]
# Скомпилируем модель, используя в качестве функции потерь  среднеквадратичную ошибку MSE с оптимизатором по умолчанию (RmsProp):

# %%
large_model.compile(loss='mse')

# %% [markdown]
# Обучим модель на наборе данных из двух признаков:

# %%
history = large_model.fit(
    X, y,
    epochs=100,
    # уровень выводимой информации
    verbose=1,
    # проверка (валидация) на 30% обучающих данных
    validation_split = 0.3)

# %% [markdown]
# Кривые обучения в зависимости от эпохи обучения выглядят так:

# %%
plot_loss(history)

# %% [markdown]
# Для визуализации прогнозируемых множественной регрессией значений воспользуемся функцией `plot_surface`. Потребуются определенные усилия по подготовке данных для `plot_surface`:

# %%
n_plot = 51

x_plot = np.linspace(np.min(xs), np.max(xs), n_plot)
y_plot = np.linspace(np.min(ys), np.max(ys), n_plot)

# %%
x_mesh, y_mesh = np.meshgrid(x_plot, y_plot)
x_mesh.shape, y_mesh.shape

# %%
x_plot2 = np.reshape(x_mesh, [n_plot**2,1])
y_plot2 = np.reshape(y_mesh, [n_plot**2,1])
xy_2 = np.hstack([x_plot2, y_plot2])
xy_2.shape

# %% [markdown]
# Теперь выполним прогнозирование при помощи обученной ранее модели, после чего вернемся к форме данных 51 на 51:

# %%
print(xy_2[0:5])
z = large_model.predict(xy_2)
z.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 print(xy_2[0:5])
#       2 z = large_model.predict(xy_2)
#       3 z.shape
#
# NameError: name 'xy_2' is not defined

# %%
z_mesh = z.reshape((n_plot, n_plot))
z_mesh.shape

# %% [markdown]
# Функция `plot_surface` имеет большое число параметров, в частности:
#
# * X, Y, Z : 2D массивы – данные для построения поверхности.
# * rstride, cstride : int – параметры определяют величину шага, с которым будут браться элементы строки/столбца из переданных массивов.
# * cmap: Colormap – цветовая карта для элементов поверхности.

# %%
from matplotlib import cm

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(x_mesh, y_mesh, z_mesh, \
       rstride=1, cstride=1, linewidth=0.05, cmap=cm.winter, antialiased=True, \
       edgecolors='gray')
ax.scatter( xs, ys, zs, s=100, c='r' )

ax.set_xlabel('Рост', fontsize=14)
ax.set_ylabel('Вес', fontsize=14)
ax.set_zlabel('Возраст', fontsize=14)
ax.set_title('Демографические данные обитателей Калахари', fontsize=16)

ax.set_zlim(0., z_mesh.max())
ax.view_init(elev = 20, azim = 120)

# %% [markdown]
# __Кривые обучения__ — это графическое представление зависимости меры (показателя) качества обучения (по вертикальной оси) от определенного показателя модели обучения (по горизонтальной оси). Будем визуализировать в качестве качества модели показатели RMSE для части обучающей выборки и тестовой выборки в зависимости от количества точек в обучающей выборке.
#
# Для разбиения на обучающую и тестовую выборки можно использовать функцию `train_test_split`:

# %%
def train_test_split(X, y, test_ratio=0.2, seed=None):
    """возвращает X_train, X_test, y_train, y_test"""
    assert X.shape[0] == y.shape[0], \
        "Размер X должен быть равен размеру y"
    assert 0.0 <= test_ratio <= 1.0, \
        "Неверное значение test_ratio"

    if seed:
        np.random.seed(seed)

    shuffled_indexes = np.random.permutation(len(X))

    test_size = int(len(X) * test_ratio)
    test_indexes = shuffled_indexes[:test_size]
    train_indexes = shuffled_indexes[test_size:]

    X_train = X[train_indexes]
    y_train = y[train_indexes]

    X_test = X[test_indexes]
    y_test = y[test_indexes]

    return X_train, X_test, y_train, y_test

# %% [markdown]
# Разобьем массивы данных `X` и `y` на обучающие и тестовые данные:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 0.3)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# Будем использовать для визуализации показатель RMSE:

# %%
def my_rmse(y_test, y_predict):
    return np.sqrt(np.sum((y_predict - y_test)**2) / len(y_test))

# %% [markdown]
# Всего в обучающей выборке 381 точка, начнем с 11 точек и будем прибавлять по 10 точек на каждом шаге цикла:

# %%
train_score = []
test_score = []
for i in range(11, 382, 10):
    large_model = tf.keras.Sequential([
        feature_normalizer,
#        tf.keras.layers.Dense(units=64, activation='relu'),
#        tf.keras.layers.Dense(units=64, activation='relu'),
#        tf.keras.layers.Dense(units=64, activation='relu'),
        tf.keras.layers.Dense(units=64, activation='relu'),
        tf.keras.layers.Dense(units=1)
    ])
    large_model.compile(loss='mse')
    large_model.fit(X_train[:i], y_train[:i], epochs=50, verbose=0)

    y_train_predict = large_model.predict(X_train[:i])
    train_score.append(my_rmse(y_train[:i], y_train_predict))

    y_test_predict = large_model.predict(X_test)
    test_score.append(my_rmse(y_test, y_test_predict))
    print('-->', i, ' done')

# %%
plt.plot([i for i in range(11, len(X_train)+1, 10)],
                               train_score, label="train")
plt.plot([i for i in range(11, len(X_train)+1, 10)],
                               test_score, label="test")
plt.legend();

# %% [markdown]
# #### Задание (10 баллов)
#
# Для закрепленного за Вами варианта контрольной работы:
#
# 1.	Загрузите заданный в индивидуальном задании набор данных из Tensorflow Datasets, включая указанные в задании независимый признак и зависимый признак (отклик). Оставьте в наборе признаки, принимающие числовые значения.
# 2.	Удалите из набора точки с выбросами при помощи стандартизованной оценки (Z-score) таким образом, чтобы точки с выбросами составляли от 5% до 10% всех точек набора данных. Визуализируйте точки исходного набора данных на плоскости в виде диаграммы рассеяния (ось X – независимый признак, ось Y – зависимый признак), показывая оставленные в наборе точки и удаленные точки разными цветами, подписывая оси и рисунок и создавая легенду.
# 3.	Выполните стандартизацию независимого признака и масштабирование на интервал [-1, 1] зависимого признака. Решите задачи линейной регрессии и полиномиальной регрессии для степени полинома, указанной в индивидуальном задании, при помощи нейронных сетей с одним нейроном и оцените качество полученных моделей по показателю, указанному в индивидуальном задании. Отследите обучение нейронных сетей, изменяя, при необходимости, гиперпараметры (функцию потерь, оптимизатор, шаг обучения и т.п.) или применяя регуляризацию.
# 4.	Постройте кривые обучения для построенных нейронных сетей с зависимостью от количества эпох. На визуализации создайте легенду.
# 5.	Визуализируйте точки набора данных на плоскости в виде диаграммы рассеяния (ось X – независимый признак, ось Y – зависимый признак), а также линии линейной и полиномиальной регрессий (другими цветами), подписывая оси и рисунок и создавая легенду.
# 6.	Определите в исходном наборе данных признак (отличный от независимого и зависимого признаков), принимающий непрерывные значения и имеющий свойства, указанные в индивидуальном задании.
# 7.	Стандартизуйте этот признак и визуализируйте его в соответствии с индивидуальным заданием.
# 8.	Сформируйте набор входных данных из двух стандартизованных признаков набора данных (независимый признак и определенный признак), постройте нейронную сеть (нелинейный регресор) с количеством скрытых слоев, количеством нейронов и функцией активации, указанными в индивидуальном задании, и одним нейроном в выходном слое и обучите ее на наборе данных из двух признаков и отклика. Отследите обучение нейронной сети, изменяя, при необходимости, гиперпараметры (функцию потерь, оптимизатор, шаг обучения и т.п.) или применяя регуляризацию.
# 9.	Визуализируйте набор данных в виде диаграммы рассеяния и прогноз нейронной сети в виде поверхности в трехмерном пространстве, подписывая оси и рисунок.
# 10.	Разбейте набор данных из двух признаков и отклика на обучающую и тестовую выборки и постройте кривые обучения для заданного показателя качества в зависимости от количества точек в обучающей выборке, подписывая оси и рисунок и создавая легенду.
